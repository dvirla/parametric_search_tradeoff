# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
claims_df = pd.read_csv("../results/musique/analysis/gemini-3-pro_claim_level.csv")
question_level_df = pd.read_csv("../results/musique/analysis/gemini-3-pro_question_level.csv")

# %%
claims_df[claims_df['example_id'] == '4hop1__562740_49925_13759_736921'][['claim_text', 'assigned_hop', 'hop_similarity', 'is_bridging', 'search_entailment', 'pk_available', 'provenance']]
# Out:
#                                                                                     claim_text  \
# 0                                             Altarage is associated with the Catholic Church.
# 1     Altarage refers to income or fees from the altar, such as indulgences and mass stipends.
# 2                                          Martin Luther sought to reform the Catholic Church.
# 3                                                         Martin Luther died in February 1546.
# 4   Martin Luther preached a sermon on Marian devotion in Wittenberg shortly before his death.
# 5                                                 The sermon was preached on January 17, 1546.
# 6                                             The sermon took place at the Church of St. Mary.
# 7             In this sermon, Martin Luther praised the Virgin Mary as the purest and holiest.
# 8                                     Wittenberg is the capital of the district of Wittenberg.
# ...
